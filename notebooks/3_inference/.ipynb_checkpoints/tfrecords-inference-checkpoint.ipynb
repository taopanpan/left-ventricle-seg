# %% [markdown]
# ### Imports

# %%
% matplotlib inline

import sys
import os
os.chdir('../..')
sys.path.append('../..')

from io import BytesIO
from pathlib import Path

import menpo.io as mio
import tensorflow as tf
from menpo.visualize import print_progress
from project.utils import tfrecords

# %% [markdown]
# # Generate TFRecords files
#
# The recommended format for TensorFlow is a TFRecords file containing `tf.train.Example` protocol buffers (which contain `Features` as a field).
#
# Here is a little program that gets your data, stuffs it in an `Example` protocol buffer, serializes the protocol buffer to a string, and then writes the string to a TFRecords file using the `tf.python_io.TFRecordWriter`.

# %%
""" Functions for writing TFRecord features """


def _int_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))


def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))


def _float_feature(value):
    return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))


def get_jpg_string(image):
    # Gets the serialized jpg from a menpo `Image`.
    fp = BytesIO()
    mio.export_image(image, fp, extension='jpg')
    fp.seek(0)
    return fp.read()

# %%
def face_iterator(images):
    """ Given an iterable of images, returns a generator of cat face data """
    for idx, img in enumerate(print_progress(images, end_with_newline=False)):
        image_name = img.path.name

        yield image_name, img


def generate(iterator,
             store_path='./',
             record_name='inference.tfrecords',
             store_records=True):
    store_path = Path(store_path)

    if store_records:
        writer = tf.python_io.TFRecordWriter(str(store_path / record_name))

    for img_name, pimg in iterator:
        
        # resize image to 256 * 256
        cimg = pimg.resize([256, 256])

        img_path = store_path / '{}'.format(img_name)

        if store_records:
            try:
                # construct the Example proto object
                example = tf.train.Example(
                    features=tf.train.Features(
                        # Features contains a map of string to Feature proto objects
                        feature={
                            # images
                            'image': tfrecords.bytes_feature(get_jpg_string(cimg)),
                            'height': tfrecords.int_feature(cimg.shape[0]),
                            'width': tfrecords.int_feature(cimg.shape[1]),
                        }))
                # use the proto object to serialize the example to a string
                serialized = example.SerializeToString()
                # write the serialized object to disk
                writer.write(serialized)

            except Exception as e:
                print('Something bad happened when processing image: "{}"'.format(img_name))
                print(e)

    if store_records:
        writer.close()

# %% [markdown]
# ## Generate TFRecords for Inference
#
# Run the following cells to generate TFRecords for a directory of images to perform inference on

# %%
# Where are the images located?
images_folder = Path('/media/taopan/data/landmark/00_project-master/data/images')

# where should the resulting TFRecords files be written to?
store_path = Path('/media/taopan/data/landmark/00_project-master/data/images')
inference_record_name = "inference.tfrecords"

# %%
# Run this to generate the TFRecord file!
from menpo.landmark import labeller, left_ventricle_34,left_ventricle_34_trimesh,left_ventricle_34_trimesh1
from menpodetect import load_dlib_left_ventricle_detector
# load the images
#images = mio.import_images(images_folder)
detector=load_dlib_left_ventricle_detector("/media/taopan/data/landmark/00_project-master/detector.svm")
def load_database(path_to_images, crop_percentage,max_diagonal=400, max_images=None):
    images = []
    # load landmarked images
    for i in mio.import_images(path_to_images, max_images=max_images, verbose=True):
           
        # convert it to grayscale if needed
        if i.n_channels == 3:
            i = i.as_greyscale(mode='luminosity')
        
        
        d = i.diagonal()
        if d > max_diagonal:
            i = i.rescale(float(max_diagonal) / d)
        bboxes = detector(i)
        #print("{} detected .".format(len(bboxes)),len(images),i.path)
        initial_bbox = bboxes[0]
        # crop image
        i = i.crop_to_pointcloud(initial_bbox,boundary=40 )
        # append it to the list
        images.append(i)
    return images
crop_percentage = 0.5
path_to_lfpw = images_folder
images = load_database(path_to_lfpw,crop_percentage)
print('Found {} assets'.format(len(images)))

# generate TFRecords
generate(face_iterator(images), store_path, inference_record_name,
         store_records=True)
# Out:
# Found 163 assets, index the returned LazyList to import.
# ('1 detected .', 0, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1-13.jpg'))
# ('1 detected .', 1, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1-18.jpg'))
# ('1 detected .', 2, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1-21.jpg'))
# ('1 detected .', 3, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1-25.jpg'))
# ('1 detected .', 4, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1048.jpg'))
# ('1 detected .', 5, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1051.jpg'))
# ('1 detected .', 6, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1055.jpg'))
# ('1 detected .', 7, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1059.jpg'))
# ('1 detected .', 8, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/110.jpg'))
# ('1 detected .', 9, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1125.jpg'))
# ('1 detected .', 10, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1132.jpg'))
# ('1 detected .', 11, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1135.jpg'))
# ('1 detected .', 12, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1138.jpg'))
# ('1 detected .', 13, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/119.jpg'))
# ('1 detected .', 14, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1207.jpg'))
# ('1 detected .', 15, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1211.jpg'))
# ('1 detected .', 16, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1215.jpg'))
# ('1 detected .', 17, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1220.jpg'))
# ('1 detected .', 18, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/13-30.jpg'))
# ('1 detected .', 19, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/13-36.jpg'))
# ('1 detected .', 20, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/13-38.jpg'))
# ('1 detected .', 21, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/130.jpg'))
# ('1 detected .', 22, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1304.jpg'))
# ('1 detected .', 23, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1310.jpg'))
# ('1 detected .', 24, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1316.jpg'))
# ('1 detected .', 25, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1321.jpg'))
# ('1 detected .', 26, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/14-111.jpg'))
# ('1 detected .', 27, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/14-78.jpg'))
# ('1 detected .', 28, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/14-83.jpg'))
# ('1 detected .', 29, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/14-85.jpg'))
# ('1 detected .', 30, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/142.jpg'))
# ('1 detected .', 31, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1438.jpg'))
# ('1 detected .', 32, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1450.jpg'))
# ('1 detected .', 33, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1452.jpg'))
# ('1 detected .', 34, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1461.jpg'))
# ('1 detected .', 35, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1530.jpg'))
# ('1 detected .', 36, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1538.jpg'))
# ('1 detected .', 37, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1547.jpg'))
# ('1 detected .', 38, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1570.jpg'))
# ('1 detected .', 39, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1609.jpg'))
# ('1 detected .', 40, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1615.jpg'))
# ('1 detected .', 41, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1621.jpg'))
# ('1 detected .', 42, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/1628.jpg'))
# ('1 detected .', 43, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/17-25.jpg'))
# ('1 detected .', 44, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/17-42.jpg'))
# ('1 detected .', 45, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/17-45.jpg'))
# ('1 detected .', 46, PosixPath('/media/taopan/data/landmark/00_project-master/data/images
PosixPath('/media/taopan/data/landmark/00_project-master/data/images/327.jpg'))
# ('1 detected .', 107, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/37-19.jpg'))
# ('1 detected .', 108, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/37-23.jpg'))
# ('1 detected .', 109, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/37-25.jpg'))
# ('1 detected .', 110, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/37-47.jpg'))
# ('1 detected .', 111, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/39-12.jpg'))
# ('1 detected .', 112, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/39-22.jpg'))
# ('1 detected .', 113, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/39-26.jpg'))
# ('1 detected .', 114, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/39-36.jpg'))
# ('1 detected .', 115, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/40-11.jpg'))
# ('1 detected .', 116, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/40-14.jpg'))
# ('1 detected .', 117, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/40-15.jpg'))
# ('1 detected .', 118, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/40-8.jpg'))
# ('1 detected .', 119, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/41-14.jpg'))
# ('1 detected .', 120, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/41-20.jpg'))
# ('1 detected .', 121, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/41-23.jpg'))
# ('1 detected .', 122, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/41-35.jpg'))
# ('1 detected .', 123, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/43-17.jpg'))
# ('1 detected .', 124, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/43-18.jpg'))
# ('1 detected .', 125, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/43-19.jpg'))
# ('1 detected .', 126, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/43-3.jpg'))
# ('1 detected .', 127, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/44-16.jpg'))
# ('1 detected .', 128, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/44-3.jpg'))
# ('1 detected .', 129, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/44-5.jpg'))
# ('1 detected .', 130, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/44-7.jpg'))
# ('1 detected .', 131, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/454.jpg'))
# ('1 detected .', 132, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/457.jpg'))
# ('1 detected .', 133, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/460.jpg'))
# ('1 detected .', 134, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/47-13.jpg'))
# ('1 detected .', 135, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/47-17.jpg'))
# ('1 detected .', 136, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/47-20.jpg'))
# ('1 detected .', 137, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/47-27.jpg'))
# ('1 detected .', 138, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/473.jpg'))
# ('1 detected .', 139, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/551.jpg'))
# ('1 detected .', 140, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/553.jpg'))
# ('1 detected .', 141, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/555.jpg'))
# ('1 detected .', 142, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/558.jpg'))
# ('1 detected .', 143, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/6-34.jpg'))
# ('1 detected .', 144, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/6-39.jpg'))
# ('1 detected .', 145, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/6-47.jpg'))
# ('1 detected .', 146, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/6-50.jpg'))
# ('1 detected .', 147, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/705.jpg'))
# ('1 detected .', 148, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/710.jpg'))
# ('1 detected .', 149, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/719.jpg'))
# ('1 detected .', 150, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/731.jpg'))
# ('1 detected .', 151, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/8-18.jpg'))
# ('1 detected .', 152, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/8-21.jpg'))
# ('1 detected .', 153, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/8-26.jpg'))
# ('1 detected .', 154, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/8-29.jpg'))
# ('1 detected .', 155, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/9-18.jpg'))
# ('1 detected .', 156, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/9-25.jpg'))
# ('1 detected .', 157, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/9-28.jpg'))
# ('1 detected .', 158, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/9-46.jpg'))
# ('1 detected .', 159, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/932.jpg'))
# ('1 detected .', 160, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/938.jpg'))
# ('1 detected .', 161, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/953.jpg'))
# ('1 detected .', 162, PosixPath('/media/taopan/data/landmark/00_project-master/data/images/958.jpg'))
# Found 163 assets
# [====================] 100% (163/163) - done.
